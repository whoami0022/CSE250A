# %%
import numpy as np
import math

def read_X(file):
    f = open(file, 'r')
    X = []
    data = [line.strip('\n') for line in f.readlines()]
    for i in data:
        i = i.split(" ")
        cur = []
        for j in i:
            cur.append(int(j))
        X.append(cur)
    return X


def read_Y(file):
    f = open(file, 'r')
    Y = []
    data = [line.strip('\n') for line in f.readlines()]
    for i in data:
        Y.append(int(i))
    return Y


def noise_OR(x, y, p):
    part = 1
    for i in range(len(x)):
        part *= math.pow(1 - p[i], x[i])
    if y == 1:
        v = 1 - part
    else:
        v = part
    return v


def likelihood(x, y, p, iter):
    cur = 0
    flag = 0
    for i in range(len(x)):
        cur += math.log(noise_OR(x[i], y[i], p))
        if y[i] == 1 and noise_OR(x[i], y[i], p) <= 0.5:
            flag += 1
        if y[i] == 0 and 1 - noise_OR(x[i], y[i], p) >= 0.5:
            flag += 1
    print("iter : " + str(iter) + "\tnumber of mistakes M : " + str(flag))
    return float(cur) / len(x)


def EM(x, y, p):
    cur = np.zeros(len(p))
    cnt = np.zeros(len(p))
    for i in range(len(x)):
        for j in range(len(p)):
            if x[i][j] == 1:
                cnt[j] += 1

            cur[j] += y[i] * x[i][j] * p[j] / noise_OR(X[i], Y[i], p)

    cur /= cnt
    return cur


X = read_X('../../cs250a-hw6/spectX.txt')
Y = read_Y('../../cs250a-hw6/spectY.txt')

p = [1.0 / 23 for _ in range(len(X[0]))]

iter = {0, 1, 2, 4, 8, 16, 32, 64, 128, 256}
for i in range(257):
    if i in iter:
        print("iter : " + str(i) + "\tlog-likelihood : " + str(likelihood(X, Y, p, i)))
        print('=====================================================')
    p = EM(X, Y, p)
# Out:
# iter : 0	number of mistakes M : 195
# iter : 0	log-likelihood : -1.04455974813
# =====================================================
# iter : 1	number of mistakes M : 60
# iter : 1	log-likelihood : -0.504940510121
# =====================================================
# iter : 2	number of mistakes M : 43
# iter : 2	log-likelihood : -0.410763774178
# =====================================================
# iter : 4	number of mistakes M : 42
# iter : 4	log-likelihood : -0.365127174287
# =====================================================
# iter : 8	number of mistakes M : 44
# iter : 8	log-likelihood : -0.347663211943
# =====================================================
# iter : 16	number of mistakes M : 40
# iter : 16	log-likelihood : -0.334676666671
# =====================================================
# iter : 32	number of mistakes M : 37
# iter : 32	log-likelihood : -0.322592689451
# =====================================================
# iter : 64	number of mistakes M : 37
# iter : 64	log-likelihood : -0.314831062386
# =====================================================
# iter : 128	number of mistakes M : 36
# iter : 128	log-likelihood : -0.311155817424
# =====================================================
# iter : 256	number of mistakes M : 36
# iter : 256	log-likelihood : -0.310161104242
# =====================================================
